# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 3.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.3 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.3 MB 3.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.3 MB 3.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.3 MB 3.7 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.3 MB 3.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.3 MB 2.8 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.3 MB 2.7 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 2.7 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

data = {
    "Name": ["Ann", "John"],
    "Age": [20, 22],
    "Marks": [85, 90]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Age  Marks
# 0   Ann   20     85
# 1  John   22     90
